# %%
#Importar pandas
import pandas as pd

# %%
#Creación df desde el csv: DESERCION_DE_LA_FORMACI_N_PROFESIONAL_INTEGRAL_20250419
df = pd.read_csv("DESERCION_DE_LA_FORMACI_N_PROFESIONAL_INTEGRAL_20250419.csv")

# %%
#Analisis de la dimension de las filas y columnas
df.shape
# Out:
# (42080, 15)

# %%
#Acceder a informacion del data set
df.info
# Out:
# <bound method DataFrame.info of        CODIGO_REGIONAL                NOMBRE_REGIONAL  CODIGO_CENTRO  \
# 0                   13             "REGIONAL BOLIVAR"           9304
# 1                   19               "REGIONAL CAUCA"           9113
# 2                   76               "REGIONAL VALLE"           9544
# 3                   19               "REGIONAL CAUCA"           9113
# 4                   20               "REGIONAL CESAR"           9520
# ...                ...                            ...            ...
# 42075               73              "REGIONAL TOLIMA"           9310
# 42076               54  "REGIONAL NORTE DE SANTANDER"           9119
# 42077               76               "REGIONAL VALLE"           9544
# 42078                5           "REGIONAL ANTIOQUIA"           9201
# 42079               25        "REGIONAL CUNDINAMARCA"           9513
#
#                                            NOMBRE_CENTRO  \
# ...

# %%
#Informacion de los encabezados con las 5 primeras filas y 5 ultimas filas
df
# Out:
#        CODIGO_REGIONAL                NOMBRE_REGIONAL  CODIGO_CENTRO  \
# 0                   13             "REGIONAL BOLIVAR"           9304
# 1                   19               "REGIONAL CAUCA"           9113
# 2                   76               "REGIONAL VALLE"           9544
# 3                   19               "REGIONAL CAUCA"           9113
# 4                   20               "REGIONAL CESAR"           9520
# ...                ...                            ...            ...
# 42075               73              "REGIONAL TOLIMA"           9310
# 42076               54  "REGIONAL NORTE DE SANTANDER"           9119
# 42077               76               "REGIONAL VALLE"           9544
# 42078                5           "REGIONAL ANTIOQUIA"           9201
# 42079               25        "REGIONAL CUNDINAMARCA"           9513
#
#                                            NOMBRE_CENTRO  \
# 0                       "CENTRO DE COMERCIO Y SERVICIOS"
# ...

# %%
#Nombres de las columnas
df.columns
# Out:
# Index(['CODIGO_REGIONAL', 'NOMBRE_REGIONAL', 'CODIGO_CENTRO', 'NOMBRE_CENTRO',
#        'IDENTIFICADOR_UNICO_FICHA', 'FECHA_INICIO_FICHA',
#        'FECHA_TERMINACION_FICHA', 'CODIGO_PROGRAMA', 'VERSION_PROGRAMA',
#        'NOMBRE_PROGRAMA_FORMACION', 'NIVEL_FORMACION', 'MODALIDAD_FORMACION',
#        'TOTAL_APRENDICES_MATRICULADOS', 'DESERTORES_AÑO_ACTUAL', 'PERIODO'],
#       dtype='object')

# %%
#Muestra las primeras 30 filas
df.head(30)
# Out:
#     CODIGO_REGIONAL              NOMBRE_REGIONAL  CODIGO_CENTRO  \
# 0                13           "REGIONAL BOLIVAR"           9304
# 1                19             "REGIONAL CAUCA"           9113
# 2                76             "REGIONAL VALLE"           9544
# 3                19             "REGIONAL CAUCA"           9113
# 4                20             "REGIONAL CESAR"           9520
# 5                76             "REGIONAL VALLE"           9124
# 6                17            "REGIONAL CALDAS"           9112
# 7                13           "REGIONAL BOLIVAR"           9304
# 8                11  "REGIONAL DISTRITO CAPITAL"           9405
# 9                13           "REGIONAL BOLIVAR"           9218
# 10                8         "REGIONAL ATLANTICO"           9302
# 11               20             "REGIONAL CESAR"           9520
# 12               23           "REGIONAL CORDOBA"           9115
# 13                5         "REGIONAL ANTIOQUIA"           9206
# ...

# %%
#Muestra las ultimas 30 filas
df.tail(30)
# Out:
#        CODIGO_REGIONAL                NOMBRE_REGIONAL  CODIGO_CENTRO  \
# 42050               66           "REGIONAL RISARALDA"           9121
# 42051               66           "REGIONAL RISARALDA"           9308
# 42052                5           "REGIONAL ANTIOQUIA"           9503
# 42053               76               "REGIONAL VALLE"           9311
# 42054               20               "REGIONAL CESAR"           9521
# 42055                5           "REGIONAL ANTIOQUIA"           9401
# 42056                5           "REGIONAL ANTIOQUIA"           9401
# 42057               13             "REGIONAL BOLIVAR"           9218
# 42058               88          "REGIONAL SAN ANDRES"           9539
# 42059               76               "REGIONAL VALLE"           9543
# 42060               68           "REGIONAL SANTANDER"           9309
# 42061               73              "REGIONAL TOLIMA"           9226
# 42062               68           "REGIONAL SANTANDER"           9122
# ...

# %%
#Muestra la primer fila
df.loc[1]
# Out:
# CODIGO_REGIONAL                                      19
# NOMBRE_REGIONAL                        "REGIONAL CAUCA"
# CODIGO_CENTRO                                      9113
# NOMBRE_CENTRO                     "CENTRO AGROPECUARIO"
# IDENTIFICADOR_UNICO_FICHA                      12860879
# FECHA_INICIO_FICHA                         "17/10/2023"
# FECHA_TERMINACION_FICHA                    "01/03/2025"
# CODIGO_PROGRAMA                                "635604"
# VERSION_PROGRAMA                                      1
# NOMBRE_PROGRAMA_FORMACION        "SERVICIOS DE BARISMO"
# NIVEL_FORMACION                               "TECNICO"
# MODALIDAD_FORMACION                        "PRESENCIAL"
# TOTAL_APRENDICES_MATRICULADOS                        21
# DESERTORES_AÑO_ACTUAL                                 0
# PERIODO                                          202402
# Name: 1, dtype: object

# %%
#Muestra las filas 5, 302 y 9854
df.loc [[5,302,9854]]
# Out:
#       CODIGO_REGIONAL              NOMBRE_REGIONAL  CODIGO_CENTRO  \
# 5                  76             "REGIONAL VALLE"           9124
# 302                76             "REGIONAL VALLE"           9544
# 9854               11  "REGIONAL DISTRITO CAPITAL"           9303
#
#                                           NOMBRE_CENTRO  \
# 5                         "CENTRO AGROPECUARIO DE BUGA"
# 302                "CENTRO DE BIOTECNOLOGIA INDUSTRIAL"
# 9854  "CENTRO DE GESTION DE MERCADOS, LOGISTICA Y TE...
#
#       IDENTIFICADOR_UNICO_FICHA FECHA_INICIO_FICHA FECHA_TERMINACION_FICHA  \
# 5                      12713214       "01/03/2023"            "15/12/2024"
# 302                    12920168       "26/02/2024"            "17/07/2024"
# 9854                   12907335       "06/02/2024"            "08/03/2024"
#
#      CODIGO_PROGRAMA  VERSION_PROGRAMA  \
# 5           "233101"                 1
# 302       "73310027"                 1
# 9854      "62360005"                 1
#
# ...

# %%
#Describe la columna NIVEL_FORMACION.
df.NIVEL_FORMACION.describe()
# Out:
# count         42080
# unique            7
# top       "TECNICO"
# freq          16832
# Name: NIVEL_FORMACION, dtype: object

# %%
#Describe la columna 
df.MODALIDAD_FORMACION.describe()
# Out:
# count            42080
# unique               3
# top       "PRESENCIAL"
# freq             32344
# Name: MODALIDAD_FORMACION, dtype: object

# %%
#Arroja la cantidad de variables y su frecuencia de la columna MODALIDAD_FORMACION
df["MODALIDAD_FORMACION"].value_counts()
# Out:
# MODALIDAD_FORMACION
# "PRESENCIAL"     32344
# "VIRTUAL"         9592
# "A DISTANCIA"      144
# Name: count, dtype: int64

# %%
#Describe la columna NIVEL_FORMACION
df["NIVEL_FORMACION"].value_counts()
# Out:
# NIVEL_FORMACION
# "TECNICO"                   16832
# "CURSO ESPECIAL"            14285
# "TECNOLOGO"                 10259
# "OPERARIO"                    423
# "EVENTO"                      142
# "AUXILIAR"                    128
# "PROFUNDIZACION TECNICA"       11
# Name: count, dtype: int64

# %%
#Describe la columna FECHA_INICIO_FICHA
df.FECHA_INICIO_FICHA.describe()
# Out:
# count            42080
# unique             521
# top       "22/01/2024"
# freq              1808
# Name: FECHA_INICIO_FICHA, dtype: object

# %%
#Describe la columna FECHA_TERMINACION_FICHA
df.FECHA_TERMINACION_FICHA.describe()
# Out:
# count            42080
# unique             732
# top       "16/12/2024"
# freq              2592
# Name: FECHA_TERMINACION_FICHA, dtype: object

# %%
#Describe la columna NOMBRE_PROGRAMA_FORMACION
df.NOMBRE_PROGRAMA_FORMACION.describe()
# Out:
# count                                    42080
# unique                                    2153
# top       "ANALISIS Y DESARROLLO DE SOFTWARE."
# freq                                      1541
# Name: NOMBRE_PROGRAMA_FORMACION, dtype: object

# %%
#Describe la columna NOMBRE_REGIONAL
df.NOMBRE_REGIONAL.describe()
# Out:
# count                           42080
# unique                             33
# top       "REGIONAL DISTRITO CAPITAL"
# freq                             5418
# Name: NOMBRE_REGIONAL, dtype: object

# %%
#Arroja la cantidad de variables y su frecuencia de la columna NOMBRE_REGIONAL 
df["NOMBRE_REGIONAL"].value_counts()
# Out:
# NOMBRE_REGIONAL
# "REGIONAL DISTRITO CAPITAL"      5418
# "REGIONAL ANTIOQUIA"             5140
# "REGIONAL VALLE"                 3548
# "REGIONAL CUNDINAMARCA"          2857
# "REGIONAL ATLANTICO"             2844
# "REGIONAL SANTANDER"             2335
# "REGIONAL TOLIMA"                1939
# "REGIONAL BOLIVAR"               1889
# "REGIONAL NORTE DE SANTANDER"    1499
# "REGIONAL CAUCA"                 1387
# "REGIONAL HUILA"                 1266
# "REGIONAL BOYACA"                1231
# "REGIONAL RISARALDA"             1209
# "REGIONAL CESAR"                 1111
# "REGIONAL QUINDIO"               1053
# "REGIONAL CORDOBA"                969
# "REGIONAL NARIÑO"                 865
# "REGIONAL CALDAS"                 738
# "REGIONAL SAN ANDRES"             629
# "REGIONAL META"                   608
# "REGIONAL MAGDALENA"              590
# "REGIONAL PUTUMAYO"               493
# "REGIONAL SUCRE"                  443
# "REGIONAL GUAJIRA"                430
# ...

# %%
#Describe la columna CODIGO_CENTRO
df.CODIGO_CENTRO.describe()
# Out:
# count    42080.000000
# mean      9334.255751
# std        159.473480
# min       9101.000000
# 25%       9208.000000
# 50%       9305.000000
# 75%       9515.000000
# max       9549.000000
# Name: CODIGO_CENTRO, dtype: float64

# %%
#Describe la columna CODIGO_PROGRAMA
df.CODIGO_PROGRAMA.describe()
# Out:
# count        42080
# unique        2195
# top       "228118"
# freq          1541
# Name: CODIGO_PROGRAMA, dtype: object

# %%
#Describe la columna TOTAL_APRENDICES_MATRICULADOS
df.TOTAL_APRENDICES_MATRICULADOS.describe()
# Out:
# count    42080.000000
# mean        34.391730
# std         21.347398
# min          1.000000
# 25%         22.000000
# 50%         27.000000
# 75%         35.000000
# max        208.000000
# Name: TOTAL_APRENDICES_MATRICULADOS, dtype: float64

# %%
#Arroja el promedio de la columna TOTAL_APRENDICES_MATRICULADOS
df.TOTAL_APRENDICES_MATRICULADOS.mean()
# Out:
# np.float64(34.391730038022814)

# %%
#Arroja el promedio de la columna DESERTORES_AÑO_ACTUAL
df.DESERTORES_AÑO_ACTUAL.mean()
# Out:
# np.float64(1.2495009505703423)

# %%
# Arroja la Desviacion Estandar de la columna DESERTORES_AÑO_ACTUAL
df.DESERTORES_AÑO_ACTUAL.std()
# Out:
# np.float64(6.435440771126394)

# %%
# Arroja el valor maximo de la columna DESERTORES_AÑO_ACTUAL
df.DESERTORES_AÑO_ACTUAL.max()
# Out:
# np.int64(84)

# %%
# Arroja la mediana de la columna DESERTORES_AÑO_ACTUAL
df.DESERTORES_AÑO_ACTUAL.median()
# Out:
# np.float64(0.0)

# %%
# Arroja la moda de la columna DESERTORES_AÑO_ACTUAL
df.DESERTORES_AÑO_ACTUAL.mode()
# Out:
# 0    0
# Name: DESERTORES_AÑO_ACTUAL, dtype: int64

# %%
# Arroja el percentil 25% de la columna DESERTORES_AÑO_ACTUAL
df.DESERTORES_AÑO_ACTUAL.quantile(0.25)
# Out:
# np.float64(0.0)

# %%
# Arroja el percentil 50% de la columna DESERTORES_AÑO_ACTUAL
df.DESERTORES_AÑO_ACTUAL.quantile(0.50)
# Out:
# np.float64(0.0)

# %%
# Arroja el percentil 75% de la columna DESERTORES_AÑO_ACTUAL
df.DESERTORES_AÑO_ACTUAL.quantile(0.75)
# Out:
# np.float64(0.0)

# %%
# Arroja las variables unicas de la columna NOMBRE_PROGRAMA_FORMACION
df.NOMBRE_PROGRAMA_FORMACION.unique()
# Out:
# array(['"COCINA."', '"SERVICIOS DE BARISMO"', '"SISTEMAS."', ...,
#        '"TECNICAS AVANZADAS DE DESPIGMENTACION CAPILAR"',
#        '"ELABORACION DE SUPLEMENTO ALIMENTICIO ANIMAL"',
#        '"SILVICULTURA Y APROVECHAMIENTO DE PLANTACIONES FORESTALES"'],
#       shape=(2153,), dtype=object)

# %%
# Arroja las variables unicas de la columna NIVEL_FORMACION
df.NIVEL_FORMACION.unique()
# Out:
# array(['"TECNICO"', '"TECNOLOGO"', '"CURSO ESPECIAL"', '"OPERARIO"',
#        '"AUXILIAR"', '"EVENTO"', '"PROFUNDIZACION TECNICA"'], dtype=object)

# %%
# Arroja las variables unicas de la columna TOTAL_APRENDICES_MATRICULADOS
df.TOTAL_APRENDICES_MATRICULADOS.unique()
# Out:
# array([ 33,  21,  39,  24,  22,  31,  80,  25,  32,  42,  26,  16,  40,
#         30,  34,  35,  28,  45,  20,  46,  23,  29,  97,  13,   8,  19,
#         38,  49,  27,  15,  14,  17,  18,   9,  10,  44,  54,  48,  37,
#         36,   6,  12,   7,  43,  65,  55,   1,  95,  41,  50,  11,  53,
#         51,  47,  66,   5,  61, 100,  57,  56,  90,  85,  52,   3,  72,
#        123,  63,  58,  59,  88,  69, 105, 117, 176,  98,  73,  78, 104,
#          4,  60,  99,  76,  84,   2, 208,  62,  64, 107, 133, 127,  92,
#         68, 114,  71, 109,  77,  70,  79,  81,  67, 128, 186, 106,  86,
#        102,  74, 125, 116, 101, 132,  93,  94, 120])
